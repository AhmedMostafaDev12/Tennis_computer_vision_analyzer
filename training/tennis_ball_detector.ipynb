# %%
from roboflow import Roboflow
rf = Roboflow(api_key="EokcRNKZkuCJk9An7BFs")
project = rf.workspace("tennisanalyzer-03nja").project("tennis-ball-detection-guz4t")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-1 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 3736.51it/s]

# %%
import shutil
shutil.move("tennis-ball-detection-1/train"
, "tennis-ball-detection-1/tennis-ball-detection-1/train")

shutil.move("tennis-ball-detection-1/test"
, "tennis-ball-detection-1/tennis-ball-detection-1/test")

shutil.move("tennis-ball-detection-1/valid"
, "tennis-ball-detection-1/tennis-ball-detection-1/valid")
# Out:
# 'tennis-ball-detection-1/tennis-ball-detection-1/valid'

# %%
! yolo task= detect mode=train model=yolov5lu.pt data=/teamspace/studios/this_studio/training/tennis-ball-detection-1/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.222 🚀 Python-3.12.11 torch-2.8.0+cu128 CUDA:0 (Tesla T4, 15095MiB)
# ...
